# %%
import pandas as pd
import os
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
dff=pd.read_csv(r'E:\features.csv',index_col=0) #reading features.csv file from file path
dff.head()
# Out:
#            0          1           2          3  Unnamed: 5          5  \
# 0 -217.35526   70.22338 -130.385270 -53.282898  -21.199130 -22.677622
# 1 -424.09818  109.34077  -52.919525  60.864750    0.245292  17.347328
# 2 -458.79114  121.38419  -46.520660  52.008120   -0.000384  23.783813
# 3 -413.89984  101.66373  -35.429450  53.036358    1.520217  14.886695
# 4 -446.60352  113.68541  -52.402214  60.302044    2.779428  25.073837
#
#            6          7         8          9  ...       118       119  \
# 0 -10.855970  18.294254  6.652703  14.324025  ...  1.379730  0.213528
# 1   2.095582  10.712965 -1.398613  12.310798  ...  0.174419 -0.619190
# 2   8.749806   9.052491 -0.636421  10.987134  ... -0.021542  0.335363
# 3   2.878706   7.631294 -2.215483   9.920996  ...  0.224067 -0.116308
# 4   2.803380  10.143700  3.034920  10.420083  ...  0.024161 -0.058449
#
#         120       121       122       123       124       125       126  \
# ...

# %%
dff1=dff.rename(columns={dff.columns[4]:'4'}) #renaming unnamed columns
dff1
# Out:
#               0           1           2          3          4          5  \
# 0    -217.35526   70.223380 -130.385270 -53.282898 -21.199130 -22.677622
# 1    -424.09818  109.340770  -52.919525  60.864750   0.245292  17.347328
# 2    -458.79114  121.384190  -46.520660  52.008120  -0.000384  23.783813
# 3    -413.89984  101.663730  -35.429450  53.036358   1.520217  14.886695
# 4    -446.60352  113.685410  -52.402214  60.302044   2.779428  25.073837
# ...         ...         ...         ...        ...        ...        ...
# 8727 -398.58450  135.534960  -50.725018  35.855907  -8.039597  15.110001
# 8728 -346.47420   86.348150  -45.168580  51.709873 -32.506092  -4.313032
# 8729 -303.88824  111.359450  -45.941563  35.877020  -9.130413  12.614908
# 8730 -344.11008  125.450210  -54.903440  34.891148 -19.626827   7.352660
# 8731 -315.60280   94.854805  -37.222340  46.778263  -6.728693  10.012548
#
#               6          7          8          9  ...       118       119  \
# ...

# %%
dft=pd.read_csv(r'E:\target.csv',index_col=0) # reading target.csv file 
dft.head()
# Out:
#                   0
# 0          dog_bark
# 1  children_playing
# 2  children_playing
# 3  children_playing
# 4  children_playing

# %%
dft1=dft.rename(columns={dft.columns[0]: 'Sounds'}) # renaming the unnamed column
dft1
# Out:
#                 Sounds
# 0             dog_bark
# 1     children_playing
# 2     children_playing
# 3     children_playing
# 4     children_playing
# ...                ...
# 8727          car_horn
# 8728          car_horn
# 8729          car_horn
# 8730          car_horn
# 8731          car_horn
#
# [8732 rows x 1 columns]

# %%
dfm=pd.concat([dft1,dff1],axis=1) # Joining two dataframes to get data from two different dataframes into one dataframe
dfm
# Out:
#                 Sounds          0           1           2          3  \
# 0             dog_bark -217.35526   70.223380 -130.385270 -53.282898
# 1     children_playing -424.09818  109.340770  -52.919525  60.864750
# 2     children_playing -458.79114  121.384190  -46.520660  52.008120
# 3     children_playing -413.89984  101.663730  -35.429450  53.036358
# 4     children_playing -446.60352  113.685410  -52.402214  60.302044
# ...                ...        ...         ...         ...        ...
# 8727          car_horn -398.58450  135.534960  -50.725018  35.855907
# 8728          car_horn -346.47420   86.348150  -45.168580  51.709873
# 8729          car_horn -303.88824  111.359450  -45.941563  35.877020
# 8730          car_horn -344.11008  125.450210  -54.903440  34.891148
# 8731          car_horn -315.60280   94.854805  -37.222340  46.778263
#
#               4          5          6          7          8  ...       118  \
# ...

# %%
dfm.duplicated()#checking for duplicate values
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8727    False
# 8728    False
# 8729    False
# 8730    False
# 8731    False
# Length: 8732, dtype: bool

# %%
dfm1=dfm.fillna(value=0)#filling null values with zero
dfm1

# %%
def createbarchart():
    sns.countplot(data=dfm ,y= 'Sounds')#creating function of createbarchart for bar plot visualization
    plt.show()

# %%
def createpiechart():#creating function to plot pie chart 
    value_counts_result = dfm1['Sounds'].value_counts()
    value_counts_result
    mylabels=['dog_bark','children_playing','air_conditioner','street_music','engine_idling','jackhammer','drilling','siren','car_horn','gun_shot']             
    plt.figure(figsize=(7, 7))
    plt.pie(value_counts_result,labels=mylabels)
    plt.title('Pie Chart for Sound')
    plt.show()

# %%
dfm2=dfm.describe() # Running describe() function to get descriptive analysis
# Out:
#                  0            1            2            3            4  \
# count  8732.000000  8732.000000  8732.000000  8732.000000  8732.000000
# mean   -230.184643   114.321854   -27.656820    20.384017   -12.987039
# std     129.707124    48.001692    31.378610    21.766223    15.723857
# min    -766.317750   -64.599390  -165.692210   -79.691610   -99.794170
# 25%    -313.787605    86.691675   -44.714514     9.304368   -23.082563
# 50%    -217.100455   120.122488   -24.517740    23.098722   -12.552918
# 75%    -131.428020   147.059368    -8.226402    34.558490    -2.106710
# max     129.532170   276.579530    83.811600   112.748380    44.166725
#
#                  5            6            7            8            9  ...  \
# count  8732.000000  8732.000000  8732.000000  8732.000000  8732.000000  ...
# mean     14.454811    -7.872165    11.557877    -9.561714     9.513866  ...
# std      14.681324    13.469092    11.168007    10.561338     8.663202  ...
# ...

# %%
def createheatmap(): # creating heatmap function 
    plt.figure(figsize=(15,10))
    sns.heatmap(dfm2,cmap='RdBu',linewidth=0.5)
    plt.show

# %%
x=dfm2.loc['count':'max','0':'50']#slicing data frame dfm2
x
# Out:
#                  0            1            2            3            4  \
# count  8732.000000  8732.000000  8732.000000  8732.000000  8732.000000
# mean   -230.184643   114.321854   -27.656820    20.384017   -12.987039
# std     129.707124    48.001692    31.378610    21.766223    15.723857
# min    -766.317750   -64.599390  -165.692210   -79.691610   -99.794170
# 25%    -313.787605    86.691675   -44.714514     9.304368   -23.082563
# 50%    -217.100455   120.122488   -24.517740    23.098722   -12.552918
# 75%    -131.428020   147.059368    -8.226402    34.558490    -2.106710
# max     129.532170   276.579530    83.811600   112.748380    44.166725
#
#                  5            6            7            8            9  ...  \
# count  8732.000000  8732.000000  8732.000000  8732.000000  8732.000000  ...
# mean     14.454811    -7.872165    11.557877    -9.561714     9.513866  ...
# std      14.681324    13.469092    11.168007    10.561338     8.663202  ...
# ...

# %%
def createboxplot():
    plt.boxplot(x)
    plt.show()

# %%
createboxplot()# calling createboxplot function

# %%
def createhistogram():#creating function for histogram
    plt.figure(figsize=(20,10))
    sns.histplot(data=dfm1, x='Sounds')
    plt.show()

# %%
createhistogram() #calling createhistogram function

# %%
#end---
